# %%
import pandas as pd

# %%
#Importando o dataset
tweets_0403 = pd.read_csv(r"C:\Users\Rogerio\Documents\HACKATHON TERA\Tweets\0403_preprocessado.csv", sep = ',', encoding = 'utf-8')
# Out:
# C:\Users\Rogerio\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Mostrando a primeiras 5 linhas do dataset
tweets_0403.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   id           created_at  \
# 0           0           195                   id           created_at
# 1           1           196  1246225970702548995  2020-04-03 23:59:59
# 2           2           197  1246225970551558151  2020-04-03 23:59:59
# 3           3           198  1246225969918226434  2020-04-03 23:59:59
# 4           4           199  1246225969817493505  2020-04-03 23:59:59
#
#                                            full_text               location  \
# 0                                          full_text               location
# 1  O problema né nem o corona 😑 https://t.co/lBVr...  Rj, Caxias, Conquista
# 2  @ancap_hell O mesmo Data Folha que em sua pesq...                 Brasil
# 3  @_LittleWeasley a miley falando que quer dar u...      Sao Paulo, Brazil
# 4            Eu to muito cozinheira nessa quarentena         Rio de Janeiro
#
#                                           txt_letras  \
# ...

# %%
#Vendo a quantidade de linhas e colunas do dataset
tweets_0403.shape
# Out:
# (144004, 11)

# %%
#Criando lista de palavras relacionada à 'desemprego'
lista_desemprego = ["emprego", "demissão", "demissões", "desemprego", "desempregar", "desempregado", "desempregada", "desempregados", "desempregadas", "demitido", "demitida", "demitidos", "demitidas", "demitir", "afastar", "afastamento", "afastada", "afastado"]

# %%
#Chamando o construtor DataFrame na lista
df = pd.DataFrame(lista_desemprego, columns=['txt_emoji_free'])

# %%
#Aplicando consulta ao tweet
tweets_0403.txt_emoji_free.apply(lambda x: [palavra in x for palavra in lista_desemprego])
# Out:
# 0         [False, False, False, False, False, False, Fal...
# 1         [False, False, False, False, False, False, Fal...
# 2         [False, False, False, False, False, False, Fal...
# 3         [False, False, False, False, False, False, Fal...
# 4         [False, False, False, False, False, False, Fal...
#                                 ...
# 143999    [False, False, False, False, False, False, Fal...
# 144000    [False, False, False, False, False, False, Fal...
# 144001    [False, False, False, False, False, False, Fal...
# 144002    [False, False, False, False, False, False, Fal...
# 144003    [False, False, False, False, False, False, Fal...
# Name: txt_emoji_free, Length: 144004, dtype: object

# %%
tweets_0403.txt_emoji_free.apply
# Out:
# <bound method Series.apply of 0                                                 full_text
# 1         o problema ne nem o corona  https  tco lbvrrsntoe
# 2          o mesmo data folha que em sua pesquisa disse ...
# 3          a miley falando que quer dar um role com ela ...
# 4                   eu to muito cozinheira nessa quarentena
#                                 ...
# 143999    ynw melly foi contaminado pelo virus na prisao...
# 144000    o presidente russo afirmou que a arabia saudit...
# 144001    em novo ataque bolsonaro chama jornalistas de ...
# 144002    numero de recuperados do coronavirus salta par...
# 144003    vacina oral contra coronavirus desenvolvida po...
# Name: txt_emoji_free, Length: 144004, dtype: object>

# %%
#Aplicando à uma coluna do dataset
tweets_0403['palavra_chave'] = tweets_0401.txt_emoji_free.apply(lambda x: [palavra in x for palavra in lista_desemprego])

# %%
tweets_0403.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   id           created_at  \
# 0           0           195                   id           created_at
# 1           1           196  1246225970702548995  2020-04-03 23:59:59
# 2           2           197  1246225970551558151  2020-04-03 23:59:59
# 3           3           198  1246225969918226434  2020-04-03 23:59:59
# 4           4           199  1246225969817493505  2020-04-03 23:59:59
#
#                                            full_text               location  \
# 0                                          full_text               location
# 1  O problema né nem o corona 😑 https://t.co/lBVr...  Rj, Caxias, Conquista
# 2  @ancap_hell O mesmo Data Folha que em sua pesq...                 Brasil
# 3  @_LittleWeasley a miley falando que quer dar u...      Sao Paulo, Brazil
# 4            Eu to muito cozinheira nessa quarentena         Rio de Janeiro
#
#                                           txt_letras  \
# ...

# %%
#Excluindo a primeira linha que está com o dados do cabeçalho
tweets_0403.drop(0)
# Out:
#         Unnamed: 0  Unnamed: 0.1                   id           created_at  \
# 1                1           196  1246225970702548995  2020-04-03 23:59:59
# 2                2           197  1246225970551558151  2020-04-03 23:59:59
# 3                3           198  1246225969918226434  2020-04-03 23:59:59
# 4                4           199  1246225969817493505  2020-04-03 23:59:59
# 5                5           200  1246225968651526145  2020-04-03 23:59:59
# ...            ...           ...                  ...                  ...
# 143999      143999        144194  1246150475323334657  2020-04-03 19:00:00
# 144000      144000        144195  1246150475063255040  2020-04-03 19:00:00
# 144001      144001        144196  1246150475017334790  2020-04-03 19:00:00
# 144002      144002        144197  1246150474954428419  2020-04-03 19:00:00
# 144003      144003        144198  1246150474752905217  2020-04-03 19:00:00
#
#                                                 full_text  \
# ...

# %%
#Criando coluna com verdadeiro ou falso caso haja menção de palavras de desemprego no tweet
tweets_0403['sentimento_desemprego'] = tweets_0403.palavra_chave.apply(lambda x:max(x))

# %%
tweets_0403.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   id           created_at  \
# 0           0           195                   id           created_at
# 1           1           196  1246225970702548995  2020-04-03 23:59:59
# 2           2           197  1246225970551558151  2020-04-03 23:59:59
# 3           3           198  1246225969918226434  2020-04-03 23:59:59
# 4           4           199  1246225969817493505  2020-04-03 23:59:59
#
#                                            full_text               location  \
# 0                                          full_text               location
# 1  O problema né nem o corona 😑 https://t.co/lBVr...  Rj, Caxias, Conquista
# 2  @ancap_hell O mesmo Data Folha que em sua pesq...                 Brasil
# 3  @_LittleWeasley a miley falando que quer dar u...      Sao Paulo, Brazil
# 4            Eu to muito cozinheira nessa quarentena         Rio de Janeiro
#
#                                           txt_letras  \
# ...

# %%
#Mostrando quantidade de tweets que mencionam cada classificação 
tweets_0403.groupby('sentimento_desemprego').count()
# Out:
#                        Unnamed: 0  Unnamed: 0.1      id  created_at  \
# sentimento_desemprego
# False                      143092        143092  143092      143092
# True                          912           912     912         912
#
#                        full_text  location  txt_letras  txt_acentos  \
# sentimento_desemprego
# False                     143092     97234      143092       143092
# True                         912       629         912          912
#
#                        txt_emoji_free  location_emoji_free   token  \
# sentimento_desemprego
# False                          143092                96912  143092
# True                              912                  625     912
#
#                        palavra_chave
# sentimento_desemprego
# False                         143092
# True                             912

# %%
#Mostrando quantidade de tweets que mencionam cada classificação 
tweets_0403.groupby('sentimento_desemprego').size()
# Out:
# sentimento_desemprego
# False    143092
# True        912
# dtype: int64

# %%
#Mostrando quantidade de tweets que mencionam cada classificação 
tweets_0403['sentimento_desemprego'].value_counts(True)
# Out:
# False    0.993667
# True     0.006333
# Name: sentimento_desemprego, dtype: float64

# %%
#conversão da coluna 'sentimento_desemprego' em uma lista
lista_desemprego = tweets_0403['sentimento_desemprego'].tolist()

# %%
#Quantidade de tweets que mencionam desemprego
tweets_Desemprego = sum(lista_desemprego)
print(tweets_Desemprego)
# Out:
# 912

# %%
#Quantidade total de tweets
tweets_totais = len(tweets_0403.index)
print(tweets_totais)
# Out:
# 144004

# %%
#Calculando o percentual de tweets relacionados à desemprego
percentual_desemprego=(tweets_Desemprego/tweets_totais) * 100
print('O percentual de tweets que mencionam desemprego dia 03 de abril é {:.4f}'.format(percentual_desemprego))
# Out:
# O percentual de tweets que mencionam desemprego dia 03 de abril é 0.6333

# %%
#Filtrando tweets selecionados na análise
tweets_0403.loc[(tweets_0403['sentimento_desemprego'] == 1)]
# Out:
#         Unnamed: 0  Unnamed: 0.1                   id           created_at  \
# 18              18           213  1246225963043762177  2020-04-03 23:59:58
# 432            432           627  1246225756788752386  2020-04-03 23:59:08
# 471            471           666  1246225734491934720  2020-04-03 23:59:03
# 556            556           751  1246225691730903040  2020-04-03 23:58:53
# 675            675           870  1246225624273952768  2020-04-03 23:58:37
# ...            ...           ...                  ...                  ...
# 143239      143239        143434  1246150862814273536  2020-04-03 19:01:32
# 143429      143429        143624  1246150757386199040  2020-04-03 19:01:07
# 143588      143588        143783  1246150671738568705  2020-04-03 19:00:47
# 143608      143608        143803  1246150659231096832  2020-04-03 19:00:44
# 143760      143760        143955  1246150584056582154  2020-04-03 19:00:26
#
#                                                 full_text  \
# ...
